# %% [markdown]
# <a href="https://colab.research.google.com/github/danyel-oliveira/Imersao-Dados-com-Python/blob/main/Imers%C3%A3o_Dados_com_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1 - Análise de Dados com Pandas

# %%
#importando a biblioteca Pandas#
import pandas as pd

# %%
#arquivo dentro do Python#
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
#visualização da base de Dados#
df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
#informações gerais do arquivo#
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
#entendendo mais o que na base das informações#
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
#tamanho da base# #133349 linhas e 11 colunas#
df.shape
# Out:
# (133349, 11)

# %%
#imprimir linhas e colunas#
var1, colunas = df.shape [0], df.shape[1]
print("linhas:", var1)
print("colunas:", colunas)
# Out:
# linhas: 133349
# colunas: 11

# %%
df.columns
# Out:
# Index(['ano_trabalho', 'nivel_experiencia', 'tipo_emprego', 'cargo', 'salario',
#        'moeda_salario', 'salario_em_usd', 'residencia_empregado',
#        'taxa_remoto', 'localizacao_empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
# prompt: traduza para mim todas as colunas do dataframe df para português brasiliero#

renomear_colunas = {
    'ano': 'ano',
    'nivel_experiencia': 'senioridade',
    'tipo_emprego': 'contrato',
    'cargo': 'cargo',
    'salario': 'salario',
    'moeda_salario': 'moeda_',
    'salario_em_usd': 'usd',
    'residencia_empregado': 'residencia',
    'taxa_remoto': 'remoto',
    'localizacao_empresa': 'empresa',
    'tamanho_empresa': 'tamanho_empresa'
}

df.rename(columns=renomear_colunas, inplace=True)
df.columns
# Out:
# Index(['ano_trabalho', 'senioridade', 'contrato', 'cargo', 'salario', 'moeda_',
#        'usd', 'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
#analisando as colunas#
df["senioridade"].value_counts()
# Out:
# senioridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df["contrato"].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df["remoto"].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
#promt: traduza para portugues as categorias da coluna "senioridade" da plataforma DF

senioridade = {
    'SE': 'Senior',
    'MI': 'Pleno',
    'EN': 'Júnior',
    'EX': 'Executivo'
}

df["senioridade"] = df["senioridade"].replace(senioridade)
df["senioridade"].value_counts()
# Out:
# senioridade
# Senior       77241
# Pleno        40465
# Júnior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
#prompt: traduza para portuges as categorias da coluna "contrato" do dataframe DF

contrato = {
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Tempo Parcial',
    'FL': 'Freelancer'
}

df["contrato"] = df["contrato"].replace(contrato)
df["contrato"].value_counts()
# Out:
# contrato
# Tempo Integral    132563
# Contrato             394
# Tempo Parcial        376
# Freelancer            16
# Name: count, dtype: int64

# %%
#promp: traduza para portugues as categorias da coluna "tamanho_empresa" do dataframe DF

tamanho_empresa = {
    'M': 'Médio',
    'L': 'Grande',
    'S': 'Pequeno'
}

df["tamanho_empresa"] = df["tamanho_empresa"].replace(tamanho_empresa)
df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# Médio      129561
# Grande       3574
# Pequeno       214
# Name: count, dtype: int64

# %%
remoto = {
    0: 'Presencial',
    50: 'Híbrido',
    100: 'Remoto'
}

df["remoto"] = df["remoto"].replace(remoto)
df["remoto"].value_counts()
# Out:
# remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    ano_trabalho senioridade        contrato               cargo  salario  \
# 0        2025.0      Senior  Tempo Integral  Solutions Engineer   214000
# 1        2025.0      Senior  Tempo Integral  Solutions Engineer   136000
# 2        2025.0       Pleno  Tempo Integral       Data Engineer   158800
# 3        2025.0       Pleno  Tempo Integral       Data Engineer   139200
# 4        2025.0      Júnior  Tempo Integral       Data Engineer    90000
#
#   moeda_     usd residencia      remoto empresa tamanho_empresa
# 0    USD  214000         US      Remoto      US           Médio
# 1    USD  136000         US      Remoto      US           Médio
# 2    USD  158800         AU  Presencial      AU           Médio
# 3    USD  139200         AU  Presencial      AU           Médio
# 4    USD   90000         US  Presencial      US           Médio

# %%
df.describe(include="object")
# Out:
#        senioridade        contrato           cargo  moeda_ residencia  \
# count       133349          133349          133349  133349     133349
# unique           4               4             390      26        102
# top         Senior  Tempo Integral  Data Scientist     USD         US
# freq         77241          132563           17314  126140     119579
#
#             remoto empresa tamanho_empresa
# count       133349  133349          133349
# unique           3      95               3
# top     Presencial      US           Médio
# freq        105312  119641          129561

# %% [markdown]
# #Aula 2 - Preparação e limpeza de Dados

# %%
#importando a biblioteca Pandas#
import pandas as pd

# %%
#arquivo dentro do Python#
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4130569682.py in <cell line: 0>()
#       1 #arquivo dentro do Python#
# ----> 2 df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")
#
# NameError: name 'pd' is not defined

# %%
#visualização da base de Dados#
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1958113452.py in <cell line: 0>()
#       1 #visualização da base de Dados#
# ----> 2 df.head()
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-286341606.py in <cell line: 0>()
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
df['ano_trabalho'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2420418960.py in <cell line: 0>()
# ----> 1 df['ano_trabalho'].unique()
#
# NameError: name 'df' is not defined

# %%
#filtro dentro da base#
df[df.isnull().any(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3927915304.py in <cell line: 0>()
#       1 #filtro dentro da base#
# ----> 2 df[df.isnull().any(axis=1)]
#
# NameError: name 'df' is not defined

# %%
import numpy as np

#Criaçao de um dataframe de teste para usar de exemplo
df_salarios = pd.DataFrame({
    'nome': ["Anna", "Bruno", "Carlos", "Daniele", "Val"],
    'salario': [4000, np.nan, 5000, np.nan, 100000]
})

#calcula a média e substitui os nulos pela média e arrededonda os valores#
df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round (2))

#Calcula mediana e substitui os nulos mediana#
df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())

df_salarios
# Out:
#       nome   salario  salario_media  salario_mediana
# 0     Anna    4000.0        4000.00           4000.0
# 1    Bruno       NaN       36333.33           5000.0
# 2   Carlos    5000.0        5000.00           5000.0
# 3  Daniele       NaN       36333.33           5000.0
# 4      Val  100000.0      100000.00         100000.0

# %%
df_temperaturas = pd.DataFrame({
    "Dia":["Segunda", "Terça", "Quarta", "Quinta", "Sexta"],
    "Temperatura":[30, np.nan, np.nan, 28, 27]
})

df_temperaturas ["preenchido_bfill"] = df_temperaturas["Temperatura"].bfill()
df_temperaturas
# Out:
#        Dia  Temperatura  preenchido_bfill
# 0  Segunda         30.0              30.0
# 1    Terça          NaN              28.0
# 2   Quarta          NaN              28.0
# 3   Quinta         28.0              28.0
# 4    Sexta         27.0              27.0

# %%
df_cidades = pd.DataFrame({
    'nome': ["Anna", "Bruno", "Carlos", "Daniele", "Val"],
    'cidade': ["São Paulo", np.nan, "Curitiba", np.nan, "Belém"]
})

df_cidades['cidade_preenchida'] = df_cidades["cidade"].fillna("Não informado")
display(df_cidades)
# Out:
#       nome     cidade cidade_preenchida
# 0     Anna  São Paulo         São Paulo
# 1    Bruno        NaN     Não informado
# 2   Carlos   Curitiba          Curitiba
# 3  Daniele        NaN     Não informado
# 4      Val      Belém             Belém

# %%
df_limpo = df.dropna()

# %%
df_limpo.isnull().sum()
# Out:
# ano_trabalho            0
# nivel_experiencia       0
# tipo_emprego            0
# cargo                   0
# salario                 0
# moeda_salario           0
# salario_em_usd          0
# residencia_empregado    0
# taxa_remoto             0
# localizacao_empresa     0
# tamanho_empresa         0
# dtype: int64

# %%
df_limpo.head()
# Out:
#    ano_trabalho nivel_experiencia tipo_emprego               cargo  salario  \
# 0          2025                SE           FT  Solutions Engineer   214000
# 1          2025                SE           FT  Solutions Engineer   136000
# 2          2025                MI           FT       Data Engineer   158800
# 3          2025                MI           FT       Data Engineer   139200
# 4          2025                EN           FT       Data Engineer    90000
#
#   moeda_salario  salario_em_usd residencia_empregado  taxa_remoto  \
# 0           USD          214000                   US          100
# 1           USD          136000                   US          100
# 2           USD          158800                   AU            0
# 3           USD          139200                   AU            0
# 4           USD           90000                   US            0
#
#   localizacao_empresa tamanho_empresa
# 0                  US               M
# ...

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ano_trabalho          133339 non-null  int64
#  1   nivel_experiencia     133339 non-null  object
#  2   tipo_emprego          133339 non-null  object
#  3   cargo                 133339 non-null  object
#  4   salario               133339 non-null  int64
#  5   moeda_salario         133339 non-null  object
#  6   salario_em_usd        133339 non-null  int64
#  7   residencia_empregado  133339 non-null  object
#  8   taxa_remoto           133339 non-null  int64
#  9   localizacao_empresa   133339 non-null  object
#  10  tamanho_empresa       133339 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 12.2+ MB

# %%
#converter o tipo sem alterar o valor#
df_limpo = df_limpo.assign(ano_trabalho = df_limpo['ano_trabalho'].astype('int64'))

# %% [markdown]
# # Aula 3 - Crie gráficos e Histórias com Dados

# %%
df_limpo.head()
# Out:
#    ano_trabalho nivel_experiencia tipo_emprego               cargo  salario  \
# 0          2025                SE           FT  Solutions Engineer   214000
# 1          2025                SE           FT  Solutions Engineer   136000
# 2          2025                MI           FT       Data Engineer   158800
# 3          2025                MI           FT       Data Engineer   139200
# 4          2025                EN           FT       Data Engineer    90000
#
#   moeda_salario  salario_em_usd residencia_empregado  taxa_remoto  \
# 0           USD          214000                   US          100
# 1           USD          136000                   US          100
# 2           USD          158800                   AU            0
# 3           USD          139200                   AU            0
# 4           USD           90000                   US            0
#
#   localizacao_empresa tamanho_empresa
# 0                  US               M
# ...

# %%
df_limpo['nivel_experiencia'].value_counts().plot(kind='bar', title="Distribuição de Nível de Experiência")
# Out:
# <Axes: title={'center': 'Distribuição de Nível de Experiência'}, xlabel='nivel_experiencia'>

# %%
#BIBLIOTECAS IMPORTANTES: "MATPLOTLIB" e "SEABORN"
import seaborn as sns

# %%
#inserindo gráficos#
sns.barplot(data=df_limpo, x='nivel_experiencia', y='salario_em_usd')
# Out:
# <Axes: xlabel='nivel_experiencia', ylabel='salario_em_usd'>

# %%
import matplotlib.pyplot as plt

# %%
#definindo o tamanho da imagem#
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x='nivel_experiencia', y='salario_em_usd')
plt.title("Salário médio por nível de Experiência")
plt.xlabel("Nível de Experiência")
plt.ylabel("Salário médio anual em USD")
plt.show()

# %%
#ORDEM DO MAIOR PARA O MENOR
df_limpo.groupby("nivel_experiencia")["salario_em_usd"].mean().sort_values(ascending=False)
# Out:
# nivel_experiencia
# EX    202027.667813
# SE    172850.838301
# MI    143044.845979
# EN     99034.963267
# Name: salario_em_usd, dtype: float64

# %%
ordem = df_limpo.groupby("nivel_experiencia")["salario_em_usd"].mean().sort_values(ascending=True).index

# %%
ordem
# Out:
# Index(['EN', 'MI', 'SE', 'EX'], dtype='object', name='nivel_experiencia')

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x='nivel_experiencia', y='salario_em_usd', order=ordem)
plt.title("Salário médio por nível de Experiência")
plt.xlabel("Nível de Experiência")
plt.ylabel("Salário médio anual em USD")
plt.show()

# %%
#ditribuição salárial#
plt.figure(figsize=(10,5))
sns.histplot(df_limpo, x='salario_em_usd', bins= 50, kde=True)
plt.title("Distribuição de salários anuais")
plt.xlabel("Salário em USD")
plt.ylabel("Frequência")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df_limpo['salario_em_usd'])
plt.title("Boxplot Salário")
plt.xlabel("Salário em USD")
plt.show()

# %%
df_limpo["nivel_experiencia"] = df_limpo["nivel_experiencia"].replace(senioridade)

ordem_nivel_experiencia = ["Júnior", "Pleno", "Senior", "Executivo"]

plt.figure(figsize=(8,5))
sns.boxplot(data=df_limpo, x='nivel_experiencia', y='salario_em_usd', order=ordem_nivel_experiencia)
plt.title("Boxplot Salário por Nível de Experiência")
plt.xlabel("Nível de Experiência")
plt.ylabel("Salário em USD")
plt.show()

#promt: traduza para portugues as categorias da coluna "senioridade" da plataforma DF

senioridade = {
    'SE': 'Senior',
    'MI': 'Pleno',
    'EN': 'Júnior',
    'EX': 'Executivo'
}

# %%
#colocando COR nos gráficos#
ordem_nivel_experiencia = ["Júnior", "Pleno", "Senior", "Executivo"]

plt.figure(figsize=(8,5))
sns.boxplot(x='nivel_experiencia', y='salario_em_usd', data=df_limpo, order=ordem_nivel_experiencia, palette='Set2', hue='nivel_experiencia')
plt.title("Boxplot Salário por Nível de Experiência")
plt.xlabel("Nível de Experiência")
plt.show()

# %%
#gráficos interativos#
import plotly.express as px

# %%
import plotly.express as px

# Calculate average salary by experience level
average_salary_by_experience = df_limpo.groupby("nivel_experiencia")["salario_em_usd"].mean().reset_index()

# Create the interactive bar plot
fig = px.bar(average_salary_by_experience,
             x='nivel_experiencia',
             y='salario_em_usd',
             title='Salário Médio por Nível de Experiência',
             labels={'nivel_experiencia': 'Nível de Experiência', 'salario_em_usd': 'Salário Médio Anual em USD'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto = {
    0: 'Presencial',
    50: 'Híbrido',
    100: 'Remoto'
}

df_limpo['taxa_remoto'] = df_limpo['taxa_remoto'].replace(remoto)

remoto_contagem = df_limpo['taxa_remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho', #gráfico pizza#
          )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto = {
    0: 'Presencial',
    50: 'Híbrido',
    100: 'Remoto'
}

df_limpo['taxa_remoto'] = df_limpo['taxa_remoto'].replace(remoto)

remoto_contagem = df_limpo['taxa_remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho', #gráfico de rosca#
             hole=0.3,
          )
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Filter for Data Scientist roles
df_data_scientist = df_filtrado[df_filtrado['cargo'] == 'Data Scientist'].copy()

# Calculate the average salary by country
average_salary_by_country = df_data_scientist.groupby('localizacao_empresa')['salario_em_usd'].mean().reset_index()

# Sort by average salary for better visualization
average_salary_by_country = average_salary_by_country.sort_values(by='salario_em_usd', ascending=False)

# Create the interactive bar plot using Plotly Express
fig = px.bar(average_salary_by_country,
             x='localizacao_empresa',
             y='salario_em_usd',
             title='Salário Médio para Data Scientists por País',
             labels={'localizacao_empresa': 'País', 'salario_em_usd': 'Salário Médio Anual em USD'})

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2086340694.py in <cell line: 0>()
#       1 # Filter for Data Scientist roles
# ----> 2 df_data_scientist = df_filtrado[df_filtrado['cargo'] == 'Data Scientist'].copy()
#       3
#       4 # Calculate the average salary by country
#       5 average_salary_by_country = df_data_scientist.groupby('localizacao_empresa')['salario_em_usd'].mean().reset_index()
#
# NameError: name 'df_filtrado' is not defined

# %% [markdown]
# # Aula 4 - Construindo um Dashboar com Streamlit
#
# > Aprender a usar a biblioteca Streamlit para a criação de um dashboard interativo simples, que permite visualizar dados filtrados e gerar gráficos de forma prática.

# %% [markdown]
# https://dashboard-salarios-dados.streamlit.app/

# %% [markdown]
# 1. Criar o ambiente virtual:
#
# ```bash
# python3 -m venv .venv
# ```
#
# 2. Ativar o ambiente virtual em Windows:
#
# ```bash
# .venv\Scripts\Activate
# ```
#
# 3. Ativar o ambiente virtual em MAC/LINUX:
# ```bash
# source .venv/bin/activate
# ```
#
# 4. Criar um arquivo chamado requirements.txt e adicionar os pacotes necessários
#
# ```bash
# pandas==2.2.3
# streamlit==1.44.1
# plotly==5.24.1
# ```
#
# 5. Instalar as bibliotecas necessárias
#
# ```bash
# pip install -r requirements.txt
# ```
#
# 6. Criar a Interface do Dashboard com Streamlit
#
# 7. Realizar o deploy do Dashboard no Streamlit Cloud: https://streamlit.io/cloud

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# --- Configuração da Página ---
# Define o título da página, o ícone e o layout para ocupar a largura inteira.
st.set_page_config(
    page_title="Dashboard de Salários na Área de Dados",
    page_icon="📊",
    layout="wide",
)

# --- Carregamento dos dados ---
df = pd.read_csv("https://raw.githubusercontent.com/vqrca/dashboard_salarios_dados/refs/heads/main/dados-imersao-final.csv")

# --- Barra Lateral (Filtros) ---
st.sidebar.header("🔍 Filtros")

# Filtro de Ano
anos_disponiveis = sorted(df['ano'].unique())
anos_selecionados = st.sidebar.multiselect("Ano", anos_disponiveis, default=anos_disponiveis)

# Filtro de Senioridade
senioridades_disponiveis = sorted(df['senioridade'].unique())
senioridades_selecionadas = st.sidebar.multiselect("Senioridade", senioridades_disponiveis, default=senioridades_disponiveis)

# Filtro por Tipo de Contrato
contratos_disponiveis = sorted(df['contrato'].unique())
contratos_selecionados = st.sidebar.multiselect("Tipo de Contrato", contratos_disponiveis, default=contratos_disponiveis)

# Filtro por Tamanho da Empresa
tamanhos_disponiveis = sorted(df['tamanho_empresa'].unique())
tamanhos_selecionados = st.sidebar.multiselect("Tamanho da Empresa", tamanhos_disponiveis, default=tamanhos_disponiveis)

# --- Filtragem do DataFrame ---
# O dataframe principal é filtrado com base nas seleções feitas na barra lateral.
df_filtrado = df[
    (df['ano'].isin(anos_selecionados)) &
    (df['senioridade'].isin(senioridades_selecionadas)) &
    (df['contrato'].isin(contratos_selecionados)) &
    (df['tamanho_empresa'].isin(tamanhos_selecionados))
]

# --- Conteúdo Principal ---
st.title("🎲 Dashboard de Análise de Salários na Área de Dados")
st.markdown("Explore os dados salariais na área de dados nos últimos anos. Utilize os filtros à esquerda para refinar sua análise.")

# --- Métricas Principais (KPIs) ---
st.subheader("Métricas gerais (Salário anual em USD)")

if not df_filtrado.empty:
    salario_medio = df_filtrado['usd'].mean()
    salario_maximo = df_filtrado['usd'].max()
    total_registros = df_filtrado.shape[0]
    cargo_mais_frequente = df_filtrado["cargo"].mode()[0]
else:
    salario_medio, salario_mediano, salario_maximo, total_registros, cargo_mais_comum = 0, 0, 0, ""

col1, col2, col3, col4 = st.columns(4)
col1.metric("Salário médio", f"${salario_medio:,.0f}")
col2.metric("Salário máximo", f"${salario_maximo:,.0f}")
col3.metric("Total de registros", f"{total_registros:,}")
col4.metric("Cargo mais frequente", cargo_mais_frequente)

st.markdown("---")

# --- Análises Visuais com Plotly ---
st.subheader("Gráficos")

col_graf1, col_graf2 = st.columns(2)

with col_graf1:
    if not df_filtrado.empty:
        top_cargos = df_filtrado.groupby('cargo')['usd'].mean().nlargest(10).sort_values(ascending=True).reset_index()
        grafico_cargos = px.bar(
            top_cargos,
            x='usd',
            y='cargo',
            orientation='h',
            title="Top 10 cargos por salário médio",
            labels={'usd': 'Média salarial anual (USD)', 'cargo': ''}
        )
        grafico_cargos.update_layout(title_x=0.1, yaxis={'categoryorder':'total ascending'})
        st.plotly_chart(grafico_cargos, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de cargos.")

with col_graf2:
    if not df_filtrado.empty:
        grafico_hist = px.histogram(
            df_filtrado,
            x='usd',
            nbins=30,
            title="Distribuição de salários anuais",
            labels={'usd': 'Faixa salarial (USD)', 'count': ''}
        )
        grafico_hist.update_layout(title_x=0.1)
        st.plotly_chart(grafico_hist, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de distribuição.")

col_graf3, col_graf4 = st.columns(2)

with col_graf3:
    if not df_filtrado.empty:
        remoto_contagem = df_filtrado['remoto'].value_counts().reset_index()
        remoto_contagem.columns = ['tipo_trabalho', 'quantidade']
        grafico_remoto = px.pie(
            remoto_contagem,
            names='tipo_trabalho',
            values='quantidade',
            title='Proporção dos tipos de trabalho',
            hole=0.5
        )
        grafico_remoto.update_traces(textinfo='percent+label')
        grafico_remoto.update_layout(title_x=0.1)
        st.plotly_chart(grafico_remoto, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico dos tipos de trabalho.")

with col_graf4:
    if not df_filtrado.empty:
        df_ds = df_filtrado[df_filtrado['cargo'] == 'Data Scientist']
        media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()
        grafico_paises = px.choropleth(media_ds_pais,
            locations='residencia_iso3',
            color='usd',
            color_continuous_scale='rdylgn',
            title='Salário médio de Cientista de Dados por país',
            labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})
        grafico_paises.update_layout(title_x=0.1)
        st.plotly_chart(grafico_paises, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de países.")

# --- Tabela de Dados Detalhados ---
st.subheader("Dados Detalhados")
st.dataframe(df_filtrado)
